# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import re
import json

# %% [markdown]
# ### Scrapping Google Play Market with selenium

# %% [markdown]
# #### Getting game links to futher parse individual game info

# %%
def pg_get_games_links(url,genre=''):
    driver = webdriver.Chrome()
    driver.get(url+genre)
    scroll_pause = 1
    time.sleep(scroll_pause)   
    last_height = driver.execute_script("return document.body.scrollHeight")
    time.sleep(scroll_pause)
    # Handling loading of additional content after scrolling to the bottom
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(scroll_pause)
        new_height = driver.execute_script("return document.body.scrollHeight")
        
        if new_height == last_height:
            break
        last_height = new_height
    # Getting game links from page elements
    elems = driver.find_elements(By.XPATH, "//a[@href]")
    # end adding them into set to avoid possible duplication
    game_links = set()
    for elem in elems:
        attr = elem.get_attribute("href")
        if "details?id" in attr:
            game_links.add(attr)
            
    driver.close()
    
    return game_links

# %%
genre = 'GAME_STRATEGY'

# %%
url = 'https://play.google.com/store/apps/category/'

# %%
pglinks = pg_get_games_links(url,genre)

# %%
len(pglinks)
# Out:
# 163

# %% [markdown]
# Lets also query for *rts* and *real time strategy* to have more data

# %%
url2 = 'https://play.google.com/store/search?q=real+time+strategy&c=apps'
pglinks2 = pg_get_games_links(url2)

# %%
url3 = 'https://play.google.com/store/search?q=rts&c=apps'
pglinks3 = pg_get_games_links(url3)

# %%
len(pglinks2)
# Out:
# 30

# %%
len(pglinks3)
# Out:
# 30

# %% [markdown]
# #### Parsing each link to get needed information

# %%
def parse_link(link):
    driver.get(link)
    
    title = driver.find_element(By.TAG_NAME, 'h1').text
    
    info = driver.find_element(By.CLASS_NAME, 'w7Iutd').text.split()
    dic = dict(list(zip(info[1::2], info[::2])))
    score = dic.get('star')
    ratings = dic.get('reviews')
    installed = dic.get('Downloads')

    
    elems = driver.find_elements(By.CLASS_NAME, 'VfPpkd-vQzf8d')
    # Free games got "Install" text on the button instead of price
    price = '0' if elems[0].text == 'Install' else elems[0].text.split()[:-1]
    
    tags = []  
    for e in elems[2:]:
        e_t = e.text
        if e_t != 'See details':
            tags.append(e_t)
        else:
            break
    # Locating and clicking "More info" button    
    driver.find_elements(By.CSS_SELECTOR, '.google-material-icons.VfPpkd-kBDsod.W7A5Qb')[0].click()
    time.sleep(0.2)
    
    more_info = driver.find_elements(By.CLASS_NAME, 'reAt0')
    dev = more_info[-1].text
    release_date = more_info[-2].text
    return {
        'title': title,
        'score': score,
        'ratings': ratings,
        'installed': installed, 
        'price': price,
        'tags': tags,
        'release_date': release_date,
        'offered_by': dev
    }

# %%
pglinks.update(pglinks2, pglinks3) # Combining game links

# %%
len(pglinks)
# Out:
# 200

# %%
PG_games_data = []
driver = webdriver.Chrome()

# Iterating over links set and scrapping them individually
for l in pglinks:
    PG_games_data.append(parse_link(l))
driver.close()

# %%
pg_df = pd.DataFrame(PG_games_data)
pg_df
# Out:
#                               title score ratings installed         price
# 0    Viking Saga 1: The Cursed Ring   4.0   5.79K     100K+             0  \
# 1      Bid Wars Stars - Multiplayer   4.4   13.2K       1M+             0
# 2     World War Armies: WW2 PvP RTS   4.3   36.8K       1M+             0
# 3               Art of War: Legions   4.3    885K      50M+             0
# 4    Card Guardians: Rogue Deck RPG   4.5   28.5K       1M+             0
# ..                              ...   ...     ...       ...           ...
# 195  Kingdom War TD Premium Offline   4.4   3.22K     100K+  [UAH, 15.00]
# 196         The Battle of Polytopia   4.4    219K      10M+             0
# 197                          Warage   3.6   1.27K     100K+             0
# 198                     Age of Apes   4.6    325K      10M+             0
# 199       Elvenar - Fantasy Kingdom   4.4    150K       5M+             0
#
#                                                   tags  release_date
# 0    [Simulation, Management, Casual, Single player...  Jan 20, 2014  \
# 1    [Simulation, Casual, Multiplayer, Competitive ...  Aug 13, 2020
# 2    [Strategy, Tactics, Casual, Multiplayer, Compe...  Jun 29, 2022
# 3    [Strategy, Tactics, Single player, Stylized, L...  Oct 20, 2019
# 4    [Card, Card battler, Casual, Single player, St...  Sep 27, 2021
# ..                                                 ...           ...
# 195        [Strategy, Tower defense, Casual, Stylized]   Oct 1, 2022
# 196  [Strategy, 4X, Casual, Multiplayer, Competitiv...  Nov 30, 2016
# 197  [Strategy, Casual, Single player, Stylized, Of...  Feb 12, 2020
# 198  [Strategy, Build & battle, Multiplayer, Compet...  Jul 28, 2020
# 199  [Simulation, Management, City-building, Single...   Nov 1, 2017
#
#             offered_by
# 0              Qumaron
# 1            By Aliens
# 2    Hypemasters, Inc.
# 3     Fastone Games HK
# 4     Tapps Games - PT
# ..                 ...
# 195   Fansipan Limited
# 196        Midjiwan AB
# 197    Digital Garbage
# 198            tap4fun
# 199     InnoGames GmbH
#
# [200 rows x 8 columns]

# %%
# Getting unique tags across dataframe to look for target tags related to graphics
pg_df['tags'].explode('tags').unique()
# Out:
# array(['Simulation', 'Management', 'Casual', 'Single player', 'Stylized',
#        'Offline', 'Multiplayer', 'Competitive multiplayer', 'Strategy',
#        'Tactics', 'Stylized-realistic', 'Low poly', 'Card',
#        'Card battler', 'Tower defense', 'Play Pass', 'Pixelated',
#        'Tycoon', 'Build & battle', 'See all reviews', 'Idle',
#        '#8 top grossing strategy', 'Wargame', 'Anime',
#        '#9 top free strategy', 'Abstract', 'City-building', 'Realistic',
#        '4X', '#4 top grossing strategy', 'Role Playing',
#        'Puzzle Role-playing', 'Physics-puzzle RPG',
#        '#6 top paid strategy', 'Action', 'Platformer',
#        '#2 top free strategy', 'Tactical', '#9 top grossing strategy',
#        '#1 top paid strategy', '#1 top free strategy', 'Action-adventure',
#        'Government', 'Action-strategy', '#4 top paid strategy',
#        'Turn-based RPG', 'Life', 'Empire building', 'Survival',
#        '#10 top free strategy', '#8 top free strategy', 'Vehicle', 'Car',
#        '#5 top free strategy', 'Roguelike', '#1 top grossing strategy',
#        'Shooter', 'Vehicle combat', '#3 top grossing strategy',
#        'Bulletstorm', 'Auto chess', 'Time management',
#        '#7 top grossing strategy', 'Cartoon', 'Hack & slash',
#        '#3 top paid strategy', 'Survival horror', 'Match 3 RPG',
#        'Farming', 'MMORPG', 'MOBA', 'News & Magazines',
#        '#7 top free strategy', 'Care', 'Pet', '#6 top grossing strategy',
#        '#3 top free strategy', '#5 top paid strategy', 'Entertainment',
#        'Video Players & Editors', '#6 top free strategy'], dtype=object)

# %%
# Tags of interest
target_tags = ['Stylized', 'Stylized-realistic', 'Pixelated', 'Anime', 'Low poly', 'Cartoon', 'Realistic',]

# %%
# Querying for target dataframe
df_pg_target = pg_df[pg_df['tags'].apply(lambda x: any(tag in x for tag in target_tags))]
df_pg_target
# Out:
#                               title score ratings installed         price
# 0    Viking Saga 1: The Cursed Ring   4.0   5.79K     100K+             0  \
# 1      Bid Wars Stars - Multiplayer   4.4   13.2K       1M+             0
# 2     World War Armies: WW2 PvP RTS   4.3   36.8K       1M+             0
# 3               Art of War: Legions   4.3    885K      50M+             0
# 4    Card Guardians: Rogue Deck RPG   4.5   28.5K       1M+             0
# ..                              ...   ...     ...       ...           ...
# 195  Kingdom War TD Premium Offline   4.4   3.22K     100K+  [UAH, 15.00]
# 196         The Battle of Polytopia   4.4    219K      10M+             0
# 197                          Warage   3.6   1.27K     100K+             0
# 198                     Age of Apes   4.6    325K      10M+             0
# 199       Elvenar - Fantasy Kingdom   4.4    150K       5M+             0
#
#                                                   tags  release_date
# 0    [Simulation, Management, Casual, Single player...  Jan 20, 2014  \
# 1    [Simulation, Casual, Multiplayer, Competitive ...  Aug 13, 2020
# 2    [Strategy, Tactics, Casual, Multiplayer, Compe...  Jun 29, 2022
# 3    [Strategy, Tactics, Single player, Stylized, L...  Oct 20, 2019
# 4    [Card, Card battler, Casual, Single player, St...  Sep 27, 2021
# ..                                                 ...           ...
# 195        [Strategy, Tower defense, Casual, Stylized]   Oct 1, 2022
# 196  [Strategy, 4X, Casual, Multiplayer, Competitiv...  Nov 30, 2016
# 197  [Strategy, Casual, Single player, Stylized, Of...  Feb 12, 2020
# 198  [Strategy, Build & battle, Multiplayer, Compet...  Jul 28, 2020
# 199  [Simulation, Management, City-building, Single...   Nov 1, 2017
#
#             offered_by
# 0              Qumaron
# 1            By Aliens
# 2    Hypemasters, Inc.
# 3     Fastone Games HK
# 4     Tapps Games - PT
# ..                 ...
# 195   Fansipan Limited
# 196        Midjiwan AB
# 197    Digital Garbage
# 198            tap4fun
# 199     InnoGames GmbH
#
# [179 rows x 8 columns]

# %%
df_pg_target.dtypes
# Out:
# title           object
# score           object
# ratings         object
# installed       object
# price           object
# tags            object
# release_date    object
# offered_by      object
# dtype: object

# %%
# Convert string numbers with suffix to numeric type
def proc_suffix(val):
  # print(val)
    if not val:
        return
    rx = r'^([0-9\.]+)\s*([km]?)\+?$'
    suffixes = {'k': 1000, 'm': 1000000}
    
    match = re.match(rx, val.lower(), re.IGNORECASE)
    number = float(match.group(1))
    suffix = match.group(2)

    return number * suffixes.get(suffix) if suffix else number

# %%
proc_suffix('262k+')
# Out:
# 262000.0

# %%
df_pg_target.loc[:, ['ratings', 'installed']] = df_pg_target.loc[:, ['ratings', 'installed']].applymap(proc_suffix)
# Out:
# C:\Users\kulturkamp\AppData\Local\Temp\ipykernel_1528\2301881222.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pg_target.loc[:, ['ratings', 'installed']] = df_pg_target.loc[:, ['ratings', 'installed']].applymap(proc_suffix)

# %%
df_pg_target
# Out:
#                               title score   ratings   installed         price
# 0    Viking Saga 1: The Cursed Ring   4.0    5790.0    100000.0             0  \
# 1      Bid Wars Stars - Multiplayer   4.4   13200.0   1000000.0             0
# 2     World War Armies: WW2 PvP RTS   4.3   36800.0   1000000.0             0
# 3               Art of War: Legions   4.3  885000.0  50000000.0             0
# 4    Card Guardians: Rogue Deck RPG   4.5   28500.0   1000000.0             0
# ..                              ...   ...       ...         ...           ...
# 195  Kingdom War TD Premium Offline   4.4    3220.0    100000.0  [UAH, 15.00]
# 196         The Battle of Polytopia   4.4  219000.0  10000000.0             0
# 197                          Warage   3.6    1270.0    100000.0             0
# 198                     Age of Apes   4.6  325000.0  10000000.0             0
# 199       Elvenar - Fantasy Kingdom   4.4  150000.0   5000000.0             0
#
#                                                   tags  release_date
# 0    [Simulation, Management, Casual, Single player...  Jan 20, 2014  \
# 1    [Simulation, Casual, Multiplayer, Competitive ...  Aug 13, 2020
# 2    [Strategy, Tactics, Casual, Multiplayer, Compe...  Jun 29, 2022
# 3    [Strategy, Tactics, Single player, Stylized, L...  Oct 20, 2019
# 4    [Card, Card battler, Casual, Single player, St...  Sep 27, 2021
# ..                                                 ...           ...
# 195        [Strategy, Tower defense, Casual, Stylized]   Oct 1, 2022
# 196  [Strategy, 4X, Casual, Multiplayer, Competitiv...  Nov 30, 2016
# 197  [Strategy, Casual, Single player, Stylized, Of...  Feb 12, 2020
# 198  [Strategy, Build & battle, Multiplayer, Compet...  Jul 28, 2020
# 199  [Simulation, Management, City-building, Single...   Nov 1, 2017
#
#             offered_by
# 0              Qumaron
# 1            By Aliens
# 2    Hypemasters, Inc.
# 3     Fastone Games HK
# 4     Tapps Games - PT
# ..                 ...
# 195   Fansipan Limited
# 196        Midjiwan AB
# 197    Digital Garbage
# 198            tap4fun
# 199     InnoGames GmbH
#
# [179 rows x 8 columns]

# %%
df_pg_target.sort_values(by='installed',ascending=False).head(20)
# Out:
#                               title score     ratings    installed price
# 128                  Clash of Clans   4.5  60300000.0  500000000.0     0  \
# 111      Lords Mobile: Kingdom Wars   4.3   8280000.0  100000000.0     0
# 167        Evony: The King's Return   3.7    601000.0  100000000.0     0
# 168                    Clash Royale   4.0  36200000.0  100000000.0     0
# 39                       Mafia City   4.4   1320000.0  100000000.0     0
# 101  World of Tanks Blitz - PVP MMO   4.1   4340000.0  100000000.0     0
# 42              Plants vs. Zombies™   4.4   5620000.0  100000000.0     0
# 193    Vlogger Go Viral: Tuber Life   4.5   2230000.0   50000000.0     0
# 3               Art of War: Legions   4.3    885000.0   50000000.0     0
# 179   State of Survival: Zombie War   4.5   2260000.0   50000000.0     0
# 89   Car Driving School : Car Games   3.9    233000.0   50000000.0     0
# 31   Rise of Kingdoms: Lost Crusade   4.5   2300000.0   50000000.0     0
# 18     League of Legends: Wild Rift   3.3   2190000.0   50000000.0     0
# 29     Megapolis: City Building Sim   4.2   1500000.0   50000000.0     0
# 54                  The Grand Mafia   4.4    229000.0   10000000.0     0
# 56    Tower Crush - Defense TD Free   4.3    265000.0   10000000.0     0
# 103    South Park: Phone Destroyer™   4.5    602000.0   10000000.0     0
# 181   Rush Royale: Tower Defense TD   4.0    536000.0   10000000.0     0
# 51       Dead Ahead: Zombie Warfare   4.5    727000.0   10000000.0     0
# 97   Forge of Empires: Build a City   4.4   1080000.0   10000000.0     0
#
#                                                   tags  release_date
# 128  [#7 top grossing strategy, Strategy, Build & b...  Sep 30, 2013  \
# 111  [#3 top grossing strategy, Strategy, 4X, Multi...  Mar 11, 2016
# 167  [Strategy, Build & battle, Casual, Multiplayer...  Aug 10, 2016
# 168  [Strategy, Tactics, Casual, Multiplayer, Compe...   Mar 1, 2016
# 39   [Strategy, Build & battle, Casual, Single play...  Mar 30, 2017
# 101  [#1 top grossing strategy, Action, Shooter, Ve...   Dec 3, 2014
# 42   [#2 top free strategy, Strategy, Tactics, Sing...  Nov 13, 2014
# 193  [Simulation, Life, Single player, Stylized, Lo...  Nov 10, 2015
# 3    [Strategy, Tactics, Single player, Stylized, L...  Oct 20, 2019
# 179  [#6 top grossing strategy, Strategy, Build & b...  Aug 26, 2019
# 89   [#8 top free strategy, Simulation, Vehicle, Ca...  Sep 16, 2019
# 31   [#4 top grossing strategy, Strategy, 4X, Casua...  May 24, 2018
# 18   [#8 top grossing strategy, Strategy, Build & b...  Dec 17, 2020
# 29   [Simulation, Management, City-building, Casual...  Nov 30, 2012
# 54   [Strategy, Build & battle, Casual, Stylized, S...   Mar 4, 2021
# 56   [Strategy, Tower defense, Casual, Multiplayer,...  Oct 17, 2015
# 103  [Strategy, Tactics, Multiplayer, Competitive m...   Nov 8, 2017
# 181  [#3 top free strategy, Strategy, Build & battl...   Oct 9, 2020
# 51   [Strategy, Tactics, Casual, Single player, Sty...  Jun 20, 2017
# 97   [Strategy, Build & battle, Multiplayer, Compet...  Mar 24, 2015
#
#                    offered_by
# 128                 Supercell
# 111                   IGG.COM
# 167                   TG Inc.
# 168                 Supercell
# 39              Phantix Games
# 101           Wargaming Group
# 42            ELECTRONIC ARTS
# 193               Tapps Games
# 3            Fastone Games HK
# 179  FunPlus International AG
# 89         Spark Game Studios
# 31                LilithGames
# 18            Riot Games, Inc
# 29         Social Quantum Ltd
# 54              Phantix Games
# 56            Impossible Apps
# 103     Ubisoft Entertainment
# 181                 UPWAKE.ME
# 51                   Mobirate
# 97             InnoGames GmbH

# %%
df_pg_target.sort_values(by=['score', 'ratings', 'installed'], ascending=[False, True, False]).head(20)
# Out:
#                               title score    ratings   installed
# 23              Block Fortress: War   5.0     2070.0     10000.0  \
# 150         Defense Zone 3 Ultra HD   4.9    24000.0    500000.0
# 7           King of Defense Premium   4.8     7560.0    100000.0
# 41    Rusted Warfare - RTS Strategy   4.8    13500.0    100000.0
# 48   Video Game Tycoon idle clicker   4.8    32200.0   1000000.0
# 91   Iron Marines: RTS offline Game   4.8    79100.0   1000000.0
# 135  Kingdom Rush Vengeance TD Game   4.8    84300.0    500000.0
# 20       Dino Bash: Dinosaur Battle   4.8   140000.0   5000000.0
# 79          Kingdom Rush Origins TD   4.8   150000.0   1000000.0
# 35        Kingdom Rush Frontiers TD   4.8   180000.0   1000000.0
# 183                     Bloons TD 5   4.8   206000.0   1000000.0
# 52                      Bloons TD 6   4.8   347000.0   1000000.0
# 5    Kingdom Rush- Tower Defense TD   4.8   761000.0  10000000.0
# 49    Rise of Empires: Ice and Fire   4.8  1820000.0  10000000.0
# 80                     Slice & Dice   4.7    12200.0    500000.0
# 62                Company of Heroes   4.7    13600.0    100000.0
# 125          Merge Duck 2: Idle RPG   4.7    19500.0    500000.0
# 148       King Of Defense: Merge TD   4.7    36000.0   1000000.0
# 115    Armor Age: WW2 tank strategy   4.7    67000.0   1000000.0
# 185               Whiteout Survival   4.7   127000.0   1000000.0
#
#              price                                               tags
# 23    [UAH, 54.99]   [Strategy, Wargame, Casual, Stylized, Pixelated]  \
# 150   [UAH, 79.99]  [Strategy, Tower defense, Casual, Single playe...
# 7     [UAH, 47.99]  [Strategy, Tower defense, Casual, Single playe...
# 41    [UAH, 54.99]  [Strategy, Wargame, Casual, Multiplayer, Compe...
# 48               0  [Simulation, Management, Tycoon, Casual, Singl...
# 91               0  [Strategy, 4X, Single player, Stylized, Offlin...
# 135  [UAH, 219.99]  [Strategy, Tower defense, Casual, Single playe...
# 20               0  [Strategy, Tactics, Casual, Single player, Sty...
# 79   [UAH, 134.99]  [#4 top paid strategy, Strategy, Tower defense...
# 35    [UAH, 89.99]  [#6 top paid strategy, Strategy, Tower defense...
# 183   [UAH, 79.99]  [#5 top paid strategy, Strategy, Tower defense...
# 52   [UAH, 304.99]  [#1 top paid strategy, Strategy, Tower defense...
# 5                0  [Strategy, Tower defense, Casual, Single playe...
# 49               0  [#9 top grossing strategy, Strategy, 4X, Multi...
# 80               0  [Role Playing, Turn-based RPG, Casual, Single ...
# 62   [UAH, 159.99]                      [Strategy, Tactics, Stylized]
# 125              0  [Role Playing, Tactical, Casual, Single player...
# 148              0  [Strategy, Tower defense, Casual, Single playe...
# 115              0  [Strategy, Tactics, Multiplayer, Competitive m...
# 185              0  [Action, Action-adventure, Survival, Casual, S...
#
#      release_date                 offered_by
# 23   Oct 16, 2014            Foursaken Media
# 150  Feb 11, 2017                ARTEM KOTOV
# 7     Jul 1, 2020                    GCenter
# 41   Dec 31, 2011            Corroding games
# 48   Apr 29, 2017            Holy Cow Studio
# 91   Sep 13, 2017             Ironhide Games
# 135  Nov 21, 2018             Ironhide Games
# 20    Oct 5, 2015              Tilting Point
# 79   Nov 20, 2014             Ironhide Games
# 35   Sep 25, 2013             Ironhide Games
# 183  Dec 14, 2012                 ninja kiwi
# 52   Jun 13, 2018                 ninja kiwi
# 5    May 15, 2013             Ironhide Games
# 49   Oct 19, 2018  Long Tech Network Limited
# 80   Jul 24, 2021                       Tann
# 62    Sep 9, 2020          Feral Interactive
# 125   Sep 5, 2022        OneMore Game Studio
# 148   Jul 1, 2020                    GCenter
# 115  Feb 20, 2018             HeroCraft Ltd.
# 185   Feb 9, 2023    Century Games Pte. Ltd.

# %% [markdown]
# #### Saving Google play market games data

# %%
df_pg_target.to_csv('pg_rts_target.csv', mode='w')

# %% [markdown]
# ### Using SteamSpy api and Steam store api to get PC games info

# %% [markdown]
# #### Getting list of RTS games listed on Steam store and approximate number of owners from SteamSpy

# %%
import requests

# %%
# Making a request for all RTS-tagged games and getting response
url = 'https://steamspy.com/api.php'
params = {
        'request': 'tag', 
        'tag': 'RTS'
 }

response = requests.get(url, params=params)
data = response.json()

# %% [markdown]
# For some reason, despite steamspy api should return more info(including tags) it does not \
# Therefore tags will be collected in a separate request, and all other info can be conveniently retrieved from steam store api

# %%
list(data.values())[0]
# Out:
# {'appid': 570,
#  'name': 'Dota 2',
#  'developer': 'Valve',
#  'publisher': 'Valve',
#  'score_rank': '',
#  'positive': 1632112,
#  'negative': 347406,
#  'userscore': 0,
#  'owners': '100,000,000 .. 200,000,000',
#  'average_forever': 36832,
#  'average_2weeks': 1535,
#  'median_forever': 934,
#  'median_2weeks': 828,
#  'price': '0',
#  'initialprice': '0',
#  'discount': '0',
#  'ccu': 547671}

# %%
# Getting game id and number of owners from respone
rows = []
for game_id, game_data in data.items():
    row = {
        'game_id': game_id,
        'owners': game_data.get('owners', None),
    }
    rows.append(row)

# %%
df_steamspy_rts = pd.DataFrame(rows, columns=['game_id', 'owners'])
df_steamspy_rts
# Out:
#       game_id                      owners
# 0         570  100,000,000 .. 200,000,000
# 1      227940    10,000,000 .. 20,000,000
# 2      489520    10,000,000 .. 20,000,000
# 3      394360     5,000,000 .. 10,000,000
# 4      594570     5,000,000 .. 10,000,000
# ...       ...                         ...
# 1493  2255140                 0 .. 20,000
# 1494  1085940                 0 .. 20,000
# 1495  2240200                 0 .. 20,000
# 1496  1362480                 0 .. 20,000
# 1497  1672420                 0 .. 20,000
#
# [1498 rows x 2 columns]

# %%
def get_tags(json_data):
    row = {
        'game_id': json_data.get('appid'),
        'tags': list(json_data.get('tags').keys())
    }
    return row

# %%
url = 'https://steamspy.com/api.php'
data = []
for idd in df_steamspy_rts['game_id']:
    # Requesting individual game`s info
    params = {
            'request': 'appdetails', 
            'appid': idd
     }
    response = requests.get(url, params=params)
    row = get_tags(response.json())
    data.append(row)

# %%
df_steamspy_tags = pd.DataFrame(data)
df_steamspy_tags
# Out:
#       game_id                                               tags
# 0         570  [Free to Play, MOBA, Multiplayer, Strategy, e-...
# 1      227940  [Free to Play, World War II, FPS, Multiplayer,...
# 2      489520  [Real Time Tactics, RTS, Multiplayer, Co-op, C...
# 3      394360  [Strategy, World War II, Grand Strategy, War, ...
# 4      594570  [Strategy, Fantasy, Turn-Based Strategy, RTS, ...
# ...       ...                                                ...
# 1493  2255140  [Social Deduction, Party Game, Mystery, Strate...
# 1494  1085940  [Strategy, RTS, Action, Indie, Violent, Buildi...
# 1495  2240200  [Strategy, RTS, Tower Defense, Rogue-like, Rea...
# 1496  1362480  [Education, Science, RTS, Creature Collector, ...
# 1497  1672420  [Action, Sports, 3D Fighter, Arcade, Hack and ...
#
# [1498 rows x 2 columns]

# %% [markdown]
# #### Requesting information about each game id from Steam store api

# %%
# Parsing individual game` responce
def parse_steam_responce(json_data):
    for game_id, game_data in json_data.items():
        if game_data['success']:
            game_data = game_data['data']
            row = {
                'game_id': game_id,
                'title': game_data.get('name', None),
                'genres': [genre.get('description', None) for genre in game_data.get('genres', [])],
                'release_date': game_data.get('release_date', {}).get('date', None),
                'metacritic_score': game_data.get('metacritic', {}).get('score', None),
                'categories': [category.get('description', None) for category in game_data.get('categories', [])],
                'price_usd': game_data.get('price_overview', {}).get('final', None)/100 if 'price_overview' in game_data else None,
                'developers': game_data.get('developers', []),
                'publishers': game_data.get('publishers', [])
            }
            return row
    return {'game_id': game_id}

# %%
url = 'https://store.steampowered.com/api/appdetails/'
l = len(df_steamspy_rts['game_id'])

# %%
from IPython.display import clear_output

# %% [markdown]
# **! Unfortunately, Steam store api has a limit of 200 requests per 5 minutes, so reqiuesting should be paused for 300 seconds every 200 requests**

# %%
data = []
count = 0
for idd in df_steamspy_rts['game_id']:
    # Requesting individual game`s info
    params = {
        'appids':  idd,
        'cc': 'us',  
    }
    response = requests.get(url, params=params)
    steam_game_data = response.json()
    # Parcing response
    row = parse_steam_responce(steam_game_data)
    data.append(row)
    
    count += 1
    clear_output(wait=True)
    print(f'requests made: {count}; requests remaining: {l-count}; progress: {(count*100)/l:.2f}%')
    # Waiting for 300 seconds every 200 requests
    if count%200 == 0:
        time.sleep(300)
# Out:
# requests made: 1498; requests remaining: 0; progress: 100.00%

# %%
len(data)
# Out:
# 1498

# %%
len(df_steamspy_rts['game_id'])
# Out:
# 1498

# %%
df_steam_info = pd.DataFrame(data)
df_steam_info
# Out:
#       game_id                    title
# 0         570                   Dota 2  \
# 1      227940        Heroes & Generals
# 2      489520           Minion Masters
# 3      394360        Hearts of Iron IV
# 4      594570  Total War: WARHAMMER II
# ...       ...                      ...
# 1493  2255140           Paranoia Party
# 1494  1085940      Orders Of The Ruler
# 1495  2240200               Final Fort
# 1496  1362480   战地细胞（Battlefield Cell）
# 1497  1672420           Wing Chun PSBL
#
#                                                  genres  release_date
# 0                      [Action, Free to Play, Strategy]   Jul 9, 2013  \
# 1     [Action, Free to Play, Indie, Massively Multip...  Oct 18, 2016
# 2     [Action, Adventure, Free to Play, Indie, RPG, ...  May 24, 2019
# 3                                [Simulation, Strategy]   Jun 6, 2016
# 4                                    [Action, Strategy]  Sep 28, 2017
# ...                                                 ...           ...
# 1493            [Casual, Free to Play, Indie, Strategy]  Feb 11, 2023
# 1494                          [Action, Indie, Strategy]  Mar 27, 2023
# 1495              [Casual, Indie, Simulation, Strategy]  Feb 21, 2023
# 1496                      [Indie, Simulation, Strategy]   Aug 4, 2022
# 1497                            [Action, Indie, Sports]  Aug 24, 2021
#
#       metacritic_score                                         categories
# 0                 90.0  [Multi-player, Co-op, Steam Trading Cards, Ste...  \
# 1                  NaN  [Multi-player, MMO, PvP, Online PvP, Co-op, On...
# 2                  NaN  [Single-player, Multi-player, PvP, Online PvP,...
# 3                 83.0  [Single-player, Multi-player, Co-op, Cross-Pla...
# 4                 87.0  [Single-player, Multi-player, PvP, Online PvP,...
# ...                ...                                                ...
# 1493               NaN  [Multi-player, PvP, Online PvP, Includes level...
# 1494               NaN     [Single-player, Multi-player, PvP, Online PvP]
# 1495               NaN                                    [Single-player]
# 1496               NaN                                    [Single-player]
# 1497               NaN           [Single-player, Full controller support]
#
#       price_usd                                         developers
# 0           NaN                                            [Valve]  \
# 1           NaN                                     [TLM Partners]
# 2           NaN                                        [BetaDwarf]
# 3         11.99                       [Paradox Development Studio]
# 4         59.99  [CREATIVE ASSEMBLY, Feral Interactive (Mac), F...
# ...         ...                                                ...
# 1493        NaN                                        [axilirate]
# 1494      34.99                                        [E2D2Works]
# 1495       3.99                                 [CloudDreamStudio]
# 1496       1.99                                           [E-Cell]
# 1497       4.99                                   [KotarosDevgame]
#
#                                              publishers
# 0                                               [Valve]
# 1                                        [TLM Partners]
# 2                                           [BetaDwarf]
# 3                                 [Paradox Interactive]
# 4     [SEGA, Feral Interactive (Mac), Feral Interact...
# ...                                                 ...
# 1493                                        [axilirate]
# 1494                                        [E2D2Works]
# 1495                                 [CloudDreamStudio]
# 1496                                           [E-Cell]
# 1497                                   [KotarosDevgame]
#
# [1498 rows x 9 columns]

# %% [markdown]
# #### Merging dataframes to get full game info

# %%
df_steam_full = df_steam_info.merge(df_steamspy_rts, on = 'game_id')
df_steam_full
# Out:
#       game_id                    title
# 0         570                   Dota 2  \
# 1      227940        Heroes & Generals
# 2      489520           Minion Masters
# 3      394360        Hearts of Iron IV
# 4      594570  Total War: WARHAMMER II
# ...       ...                      ...
# 1493  2255140           Paranoia Party
# 1494  1085940      Orders Of The Ruler
# 1495  2240200               Final Fort
# 1496  1362480   战地细胞（Battlefield Cell）
# 1497  1672420           Wing Chun PSBL
#
#                                                  genres  release_date
# 0                      [Action, Free to Play, Strategy]   Jul 9, 2013  \
# 1     [Action, Free to Play, Indie, Massively Multip...  Oct 18, 2016
# 2     [Action, Adventure, Free to Play, Indie, RPG, ...  May 24, 2019
# 3                                [Simulation, Strategy]   Jun 6, 2016
# 4                                    [Action, Strategy]  Sep 28, 2017
# ...                                                 ...           ...
# 1493            [Casual, Free to Play, Indie, Strategy]  Feb 11, 2023
# 1494                          [Action, Indie, Strategy]  Mar 27, 2023
# 1495              [Casual, Indie, Simulation, Strategy]  Feb 21, 2023
# 1496                      [Indie, Simulation, Strategy]   Aug 4, 2022
# 1497                            [Action, Indie, Sports]  Aug 24, 2021
#
#       metacritic_score                                         categories
# 0                 90.0  [Multi-player, Co-op, Steam Trading Cards, Ste...  \
# 1                  NaN  [Multi-player, MMO, PvP, Online PvP, Co-op, On...
# 2                  NaN  [Single-player, Multi-player, PvP, Online PvP,...
# 3                 83.0  [Single-player, Multi-player, Co-op, Cross-Pla...
# 4                 87.0  [Single-player, Multi-player, PvP, Online PvP,...
# ...                ...                                                ...
# 1493               NaN  [Multi-player, PvP, Online PvP, Includes level...
# 1494               NaN     [Single-player, Multi-player, PvP, Online PvP]
# 1495               NaN                                    [Single-player]
# 1496               NaN                                    [Single-player]
# 1497               NaN           [Single-player, Full controller support]
#
#       price_usd                                         developers
# 0           NaN                                            [Valve]  \
# 1           NaN                                     [TLM Partners]
# 2           NaN                                        [BetaDwarf]
# 3         11.99                       [Paradox Development Studio]
# 4         59.99  [CREATIVE ASSEMBLY, Feral Interactive (Mac), F...
# ...         ...                                                ...
# 1493        NaN                                        [axilirate]
# 1494      34.99                                        [E2D2Works]
# 1495       3.99                                 [CloudDreamStudio]
# 1496       1.99                                           [E-Cell]
# 1497       4.99                                   [KotarosDevgame]
#
#                                              publishers
# 0                                               [Valve]  \
# 1                                        [TLM Partners]
# 2                                           [BetaDwarf]
# 3                                 [Paradox Interactive]
# 4     [SEGA, Feral Interactive (Mac), Feral Interact...
# ...                                                 ...
# 1493                                        [axilirate]
# 1494                                        [E2D2Works]
# 1495                                 [CloudDreamStudio]
# 1496                                           [E-Cell]
# 1497                                   [KotarosDevgame]
#
#                           owners
# 0     100,000,000 .. 200,000,000
# 1       10,000,000 .. 20,000,000
# 2       10,000,000 .. 20,000,000
# 3        5,000,000 .. 10,000,000
# 4        5,000,000 .. 10,000,000
# ...                          ...
# 1493                 0 .. 20,000
# 1494                 0 .. 20,000
# 1495                 0 .. 20,000
# 1496                 0 .. 20,000
# 1497                 0 .. 20,000
#
# [1498 rows x 10 columns]

# %%
df_steam_full.loc[:, 'game_id'] = df_steam_full.loc[:, 'game_id'].astype(int)
df_steam_full= df_steam_full.merge(df_steamspy_tags, on='game_id')
df_steam_full
# Out:
#       game_id                    title
# 0         570                   Dota 2  \
# 1      227940        Heroes & Generals
# 2      489520           Minion Masters
# 3      394360        Hearts of Iron IV
# 4      594570  Total War: WARHAMMER II
# ...       ...                      ...
# 1493  2255140           Paranoia Party
# 1494  1085940      Orders Of The Ruler
# 1495  2240200               Final Fort
# 1496  1362480   战地细胞（Battlefield Cell）
# 1497  1672420           Wing Chun PSBL
#
#                                                  genres  release_date
# 0                      [Action, Free to Play, Strategy]   Jul 9, 2013  \
# 1     [Action, Free to Play, Indie, Massively Multip...  Oct 18, 2016
# 2     [Action, Adventure, Free to Play, Indie, RPG, ...  May 24, 2019
# 3                                [Simulation, Strategy]   Jun 6, 2016
# 4                                    [Action, Strategy]  Sep 28, 2017
# ...                                                 ...           ...
# 1493            [Casual, Free to Play, Indie, Strategy]  Feb 11, 2023
# 1494                          [Action, Indie, Strategy]  Mar 27, 2023
# 1495              [Casual, Indie, Simulation, Strategy]  Feb 21, 2023
# 1496                      [Indie, Simulation, Strategy]   Aug 4, 2022
# 1497                            [Action, Indie, Sports]  Aug 24, 2021
#
#       metacritic_score                                         categories
# 0                 90.0  [Multi-player, Co-op, Steam Trading Cards, Ste...  \
# 1                  NaN  [Multi-player, MMO, PvP, Online PvP, Co-op, On...
# 2                  NaN  [Single-player, Multi-player, PvP, Online PvP,...
# 3                 83.0  [Single-player, Multi-player, Co-op, Cross-Pla...
# 4                 87.0  [Single-player, Multi-player, PvP, Online PvP,...
# ...                ...                                                ...
# 1493               NaN  [Multi-player, PvP, Online PvP, Includes level...
# 1494               NaN     [Single-player, Multi-player, PvP, Online PvP]
# 1495               NaN                                    [Single-player]
# 1496               NaN                                    [Single-player]
# 1497               NaN           [Single-player, Full controller support]
#
#       price_usd                                         developers
# 0           NaN                                            [Valve]  \
# 1           NaN                                     [TLM Partners]
# 2           NaN                                        [BetaDwarf]
# 3         11.99                       [Paradox Development Studio]
# 4         59.99  [CREATIVE ASSEMBLY, Feral Interactive (Mac), F...
# ...         ...                                                ...
# 1493        NaN                                        [axilirate]
# 1494      34.99                                        [E2D2Works]
# 1495       3.99                                 [CloudDreamStudio]
# 1496       1.99                                           [E-Cell]
# 1497       4.99                                   [KotarosDevgame]
#
#                                              publishers
# 0                                               [Valve]  \
# 1                                        [TLM Partners]
# 2                                           [BetaDwarf]
# 3                                 [Paradox Interactive]
# 4     [SEGA, Feral Interactive (Mac), Feral Interact...
# ...                                                 ...
# 1493                                        [axilirate]
# 1494                                        [E2D2Works]
# 1495                                 [CloudDreamStudio]
# 1496                                           [E-Cell]
# 1497                                   [KotarosDevgame]
#
#                           owners
# 0     100,000,000 .. 200,000,000  \
# 1       10,000,000 .. 20,000,000
# 2       10,000,000 .. 20,000,000
# 3        5,000,000 .. 10,000,000
# 4        5,000,000 .. 10,000,000
# ...                          ...
# 1493                 0 .. 20,000
# 1494                 0 .. 20,000
# 1495                 0 .. 20,000
# 1496                 0 .. 20,000
# 1497                 0 .. 20,000
#
#                                                    tags
# 0     [Free to Play, MOBA, Multiplayer, Strategy, e-...
# 1     [Free to Play, World War II, FPS, Multiplayer,...
# 2     [Real Time Tactics, RTS, Multiplayer, Co-op, C...
# 3     [Strategy, World War II, Grand Strategy, War, ...
# 4     [Strategy, Fantasy, Turn-Based Strategy, RTS, ...
# ...                                                 ...
# 1493  [Social Deduction, Party Game, Mystery, Strate...
# 1494  [Strategy, RTS, Action, Indie, Violent, Buildi...
# 1495  [Strategy, RTS, Tower Defense, Rogue-like, Rea...
# 1496  [Education, Science, RTS, Creature Collector, ...
# 1497  [Action, Sports, 3D Fighter, Arcade, Hack and ...
#
# [1498 rows x 11 columns]

# %%
df_steam_full['tags'].explode('tags').unique()
# Out:
# array(['Free to Play', 'MOBA', 'Multiplayer', 'Strategy', 'e-sports',
#        'Team-Based', 'Competitive', 'Action', 'Online Co-Op', 'PvP',
#        'Difficult', 'Co-op', 'RTS', 'Tower Defense', 'RPG', 'Fantasy',
#        'Character Customization', 'Replay Value', 'Action RPG',
#        'Simulation', 'World War II', 'FPS', 'War', 'Shooter',
#        'First-Person', 'Massively Multiplayer', 'Tactical', 'Historical',
#        'Open World', 'Atmospheric', 'Adventure', 'Indie', 'Early Access',
#        'Real Time Tactics', 'Card Battler', 'Strategy RPG', 'Card Game',
#        'PvE', 'Deckbuilding', 'Singleplayer', 'Turn-Based Tactics',
#        'Mouse only', 'Stylized', 'Grand Strategy', 'Military',
#        'Alternate History', 'Real-Time with Pause', 'Diplomacy',
#        'Sandbox', 'Turn-Based Strategy', 'Games Workshop', 'Turn-Based',
#        'Dark Fantasy', 'Story Rich', 'Dinosaurs', 'Great Soundtrack',
#        'Warhammer 40K', 'Medieval', 'Classic', 'Base-Building',
#        'City Builder', 'Resource Management', 'Real-Time', 'Remake', '2D',
#        'Isometric', 'Tanks', 'Building', 'Colony Sim', 'Management',
#        'Top-Down', 'Economy', 'Capitalism', 'Moddable', 'Funny', 'Casual',
#        'Political', 'Nonlinear', 'Education', 'Violent', 'Destruction',
#        '4X', 'Vikings', 'Space', 'Automation', 'Sci-fi', 'Space Sim',
#        '3D', 'Third Person', 'Mechs', 'Parkour', 'Futuristic', 'Combat',
#        'Fast-Paced', 'Time Travel', 'Dating Sim', 'Hero Shooter',
#        'Exploration', 'Procedural Generation', 'Ninja', 'Political Sim',
#        'Politics', 'Rome', 'Epic', 'Addictive', 'Survival',
#        'Post-apocalyptic', 'Steampunk', 'Choices Matter', 'Dark',
#        'Swordplay', 'Wargame', 'Action RTS', 'Tactical RPG', 'Gore',
#        'Life Sim', 'Co-op Campaign', 'Colorful', 'Relaxing', 'Beautiful',
#        'Comedy', 'Music', 'Hack and Slash', 'Gothic', 'Action-Adventure',
#        "Beat 'em up", 'Vehicular Combat', 'Pirates', 'God Game', 'Cute',
#        'Science', 'Aliens', 'Cartoony', 'Family Friendly', 'Cartoon',
#        'Mars', 'Realistic', 'Naval', 'America', 'Mythology', 'Nostalgia',
#        'Mature', 'Cold War', 'Crafting', 'Zombies', 'Robots', "1990's",
#        'FMV', 'Level Editor', 'Soundtrack', 'Cinematic', 'Retro', 'Mod',
#        'CRPG', 'Party-Based RPG', 'Kickstarter', 'Physics',
#        'Pixel Graphics', 'Local Co-Op', 'Local Multiplayer', 'Platformer',
#        'Split Screen', '4 Player Local', 'Top-Down Shooter',
#        'Artificial Intelligence', 'Loot', 'Stealth', 'Assassin', 'Puzzle',
#        'Modern', 'Hex Grid', 'Female Protagonist', 'Old School',
#        'Cult Classic', 'MMORPG', 'Horror', 'Anime', 'Memes',
#        'Psychological Horror', 'Lovecraftian', 'Rogue-like', 'Rogue-lite',
#        'Visual Novel', 'Dungeon Crawler', 'Villain Protagonist', 'Nudity',
#        'World War I', 'Chess', 'Touch-Friendly', 'Cyberpunk',
#        'Class-Based', 'Dark Humor', 'Trading', 'Farming', 'Illuminati',
#        'Lemmings', 'Choose Your Own Adventure', 'Multiple Endings',
#        'Arcade', 'Magic', 'LGBTQ+', 'NSFW', 'Tabletop', 'Board Game',
#        'Survival Horror', 'Sequel', 'Crime', 'Controller', 'Mining',
#        'Idler', 'Minimalist', 'Action Roguelike', 'Perma Death',
#        'Transhumanism', 'Tutorial', 'Western', 'Underground',
#        'Dark Comedy', 'Demons', 'Turn-Based Combat', 'Naval Combat',
#        'Flight', 'Voxel', 'Spaceships', 'LEGO', 'Twin Stick Shooter',
#        'Third-Person Shooter', 'Open World Survival Craft',
#        'Immersive Sim', 'Utilities', 'Design & Illustration',
#        'Animation & Modeling', 'Software Training', 'Software',
#        'Experience', 'Submarine', 'Transportation', 'Trains', 'Logic',
#        'Blood', "Shoot 'Em Up", 'Sexual Content', 'Romance', 'Hentai',
#        'Short', 'Dog', 'Score Attack', 'Gun Customization',
#        'Interactive Fiction', 'Lore-Rich', 'Detective', 'Point & Click',
#        '2.5D', '3D Platformer', 'Dragons', 'Agriculture', 'Dystopian ',
#        'Parody ', 'Grid-Based Movement', 'Asynchronous Multiplayer',
#        'Trading Card Game', 'Character Action Game', 'Time Management',
#        'Medical Sim', 'Heist', 'Abstract', 'Dynamic Narration',
#        '3D Vision', 'Underwater', 'Nature', 'Emotional', 'Supernatural',
#        'Thriller', 'Mystery', 'Programming', 'Hacking',
#        'Inventory Management', 'Driving', 'Automobile Sim',
#        'Spectacle fighter', 'Conversation', 'Fighting', 'Auto Battler',
#        'Voice Control', '1980s', 'Linear', 'Bullet Hell', 'Faith',
#        '2D Fighter', 'Clicker', 'Hand-drawn', 'Bullet Time', 'Superhero',
#        'Comic Book', 'Creature Collector', 'Sports', 'Side Scroller',
#        'Sailing', 'Outbreak Sim', 'Foreign', 'Experimental',
#        'Battle Royale', 'Archery', 'VR', 'VR Only', '2D Platformer',
#        'Puzzle-Platformer', 'Spelling', 'Investigation', 'Narration',
#        'Looter Shooter', 'Collectathon', 'Jet', 'RPGMaker', 'JRPG',
#        'Time Manipulation', 'Farming Sim', 'Traditional Roguelike',
#        'Unforgiving', 'Sokoban', 'Metroidvania', 'Movie', 'Surreal',
#        'Arena Shooter', 'Satire', 'Drama', 'Mystery Dungeon', 'GameMaker',
#        'Gambling', 'Crowdfunded', 'Sniper', 'On-Rails Shooter', 'Offroad',
#        'Horses', 'Racing', 'Martial Arts', '3D Fighter', 'Solitaire',
#        'Philosophical', 'Quick-Time Events', 'Noir', '6DOF', 'Conspiracy',
#        'Typing', 'Text-Based', 'Football (Soccer)', 'Snow', 'Otome',
#        'Cooking', 'Hidden Object', 'Combat Racing', 'Psychological',
#        'Music-Based Procedural Generation', 'Runner', 'Hunting',
#        'Documentary', 'Game Development', 'Match 3', 'Word Game',
#        '360 Video', 'Snooker', 'Walking Simulator',
#        'Precision Platformer', 'Souls-like', 'Tennis', 'Rock Music',
#        'Immersive', 'Fishing', 'Asymmetric VR', 'Cats',
#        'Roguelike Deckbuilder', 'Psychedelic', 'Minigames', 'Wrestling',
#        'Roguevania', 'Rhythm', 'Trivia', 'Werewolves', 'Social Deduction',
#        'Time Attack', 'Skiing', 'Snowboarding', 'Cozy',
#        'Dungeons & Dragons', 'Party Game'], dtype=object)

# %%
steam_target_tags = ['Stylized', 'Realistic', 'Gothic', 'Cartoon', 'Anime', 'Minimalist']

# %%
df_steam_full['categories'].explode('categories').unique()
# Out:
# array(['Multi-player', 'Co-op', 'Steam Trading Cards', 'Steam Workshop',
#        'SteamVR Collectibles', 'In-App Purchases',
#        'Valve Anti-Cheat enabled', 'MMO', 'PvP', 'Online PvP',
#        'Online Co-op', 'Stats', 'Single-player',
#        'Cross-Platform Multiplayer', 'Steam Achievements',
#        'Full controller support', 'Steam Cloud', 'Remote Play on Tablet',
#        'LAN PvP', 'LAN Co-op', 'Captions available', 'Steam Leaderboards',
#        'Includes level editor', 'Remote Play on Phone',
#        'Remote Play on TV', 'Partial Controller Support',
#        'Shared/Split Screen', 'Remote Play Together',
#        'Commentary available', 'VR Supported', 'Steam Turn Notifications',
#        'Includes Source SDK', 'Shared/Split Screen PvP',
#        'Shared/Split Screen Co-op', nan, 'Tracked Controller Support',
#        'VR Only', 'VR Support'], dtype=object)

# %%
# Creating columns with numeric lower and upper bounds of estimated number of owners
df_steam_full['owners_min'] = df_steam_full.loc[:, 'owners'].apply(lambda x: int(x.split(' .. ')[0].replace(',', '')))
df_steam_full['owners_max'] = df_steam_full.loc[:, 'owners'].apply(lambda x: int(x.split(' .. ')[1].replace(',', '')))

# %%
df_steam_full
# Out:
#       game_id                    title
# 0         570                   Dota 2  \
# 1      227940        Heroes & Generals
# 2      489520           Minion Masters
# 3      394360        Hearts of Iron IV
# 4      594570  Total War: WARHAMMER II
# ...       ...                      ...
# 1493  2255140           Paranoia Party
# 1494  1085940      Orders Of The Ruler
# 1495  2240200               Final Fort
# 1496  1362480   战地细胞（Battlefield Cell）
# 1497  1672420           Wing Chun PSBL
#
#                                                  genres  release_date
# 0                      [Action, Free to Play, Strategy]   Jul 9, 2013  \
# 1     [Action, Free to Play, Indie, Massively Multip...  Oct 18, 2016
# 2     [Action, Adventure, Free to Play, Indie, RPG, ...  May 24, 2019
# 3                                [Simulation, Strategy]   Jun 6, 2016
# 4                                    [Action, Strategy]  Sep 28, 2017
# ...                                                 ...           ...
# 1493            [Casual, Free to Play, Indie, Strategy]  Feb 11, 2023
# 1494                          [Action, Indie, Strategy]  Mar 27, 2023
# 1495              [Casual, Indie, Simulation, Strategy]  Feb 21, 2023
# 1496                      [Indie, Simulation, Strategy]   Aug 4, 2022
# 1497                            [Action, Indie, Sports]  Aug 24, 2021
#
#       metacritic_score                                         categories
# 0                 90.0  [Multi-player, Co-op, Steam Trading Cards, Ste...  \
# 1                  NaN  [Multi-player, MMO, PvP, Online PvP, Co-op, On...
# 2                  NaN  [Single-player, Multi-player, PvP, Online PvP,...
# 3                 83.0  [Single-player, Multi-player, Co-op, Cross-Pla...
# 4                 87.0  [Single-player, Multi-player, PvP, Online PvP,...
# ...                ...                                                ...
# 1493               NaN  [Multi-player, PvP, Online PvP, Includes level...
# 1494               NaN     [Single-player, Multi-player, PvP, Online PvP]
# 1495               NaN                                    [Single-player]
# 1496               NaN                                    [Single-player]
# 1497               NaN           [Single-player, Full controller support]
#
#       price_usd                                         developers
# 0           NaN                                            [Valve]  \
# 1           NaN                                     [TLM Partners]
# 2           NaN                                        [BetaDwarf]
# 3         11.99                       [Paradox Development Studio]
# 4         59.99  [CREATIVE ASSEMBLY, Feral Interactive (Mac), F...
# ...         ...                                                ...
# 1493        NaN                                        [axilirate]
# 1494      34.99                                        [E2D2Works]
# 1495       3.99                                 [CloudDreamStudio]
# 1496       1.99                                           [E-Cell]
# 1497       4.99                                   [KotarosDevgame]
#
#                                              publishers
# 0                                               [Valve]  \
# 1                                        [TLM Partners]
# 2                                           [BetaDwarf]
# 3                                 [Paradox Interactive]
# 4     [SEGA, Feral Interactive (Mac), Feral Interact...
# ...                                                 ...
# 1493                                        [axilirate]
# 1494                                        [E2D2Works]
# 1495                                 [CloudDreamStudio]
# 1496                                           [E-Cell]
# 1497                                   [KotarosDevgame]
#
#                           owners
# 0     100,000,000 .. 200,000,000  \
# 1       10,000,000 .. 20,000,000
# 2       10,000,000 .. 20,000,000
# 3        5,000,000 .. 10,000,000
# 4        5,000,000 .. 10,000,000
# ...                          ...
# 1493                 0 .. 20,000
# 1494                 0 .. 20,000
# 1495                 0 .. 20,000
# 1496                 0 .. 20,000
# 1497                 0 .. 20,000
#
#                                                    tags  owners_min
# 0     [Free to Play, MOBA, Multiplayer, Strategy, e-...   100000000  \
# 1     [Free to Play, World War II, FPS, Multiplayer,...    10000000
# 2     [Real Time Tactics, RTS, Multiplayer, Co-op, C...    10000000
# 3     [Strategy, World War II, Grand Strategy, War, ...     5000000
# 4     [Strategy, Fantasy, Turn-Based Strategy, RTS, ...     5000000
# ...                                                 ...         ...
# 1493  [Social Deduction, Party Game, Mystery, Strate...           0
# 1494  [Strategy, RTS, Action, Indie, Violent, Buildi...           0
# 1495  [Strategy, RTS, Tower Defense, Rogue-like, Rea...           0
# 1496  [Education, Science, RTS, Creature Collector, ...           0
# 1497  [Action, Sports, 3D Fighter, Arcade, Hack and ...           0
#
#       owners_max
# 0      200000000
# 1       20000000
# 2       20000000
# 3       10000000
# 4       10000000
# ...          ...
# 1493       20000
# 1494       20000
# 1495       20000
# 1496       20000
# 1497       20000
#
# [1498 rows x 13 columns]

# %%
df_steam_target = df_steam_full[df_steam_full['tags'].apply(lambda x: any(val in x for val in steam_target_tags))]
df_steam_target
# Out:
#       game_id                   title
# 2      489520          Minion Masters  \
# 14     201270     Total War: SHOGUN 2
# 20      34330     Total War: SHOGUN 2
# 28     225260           Brutal Legend
# 30      17390                  SPORE™
# ...       ...                     ...
# 1475  1606610                 Rescuer
# 1485  2206490          Ruined Kingdom
# 1491  2307910           Pi Fu Fighter
# 1494  1085940     Orders Of The Ruler
# 1496  1362480  战地细胞（Battlefield Cell）
#
#                                                  genres  release_date
# 2     [Action, Adventure, Free to Play, Indie, RPG, ...  May 24, 2019  \
# 14                                           [Strategy]  Mar 15, 2011
# 20                                           [Strategy]  Mar 15, 2011
# 28                        [Action, Adventure, Strategy]  Feb 26, 2013
# 30    [Action, Adventure, Casual, RPG, Simulation, S...  Dec 19, 2008
# ...                                                 ...           ...
# 1475       [Action, Adventure, Casual, Indie, Strategy]   Aug 6, 2021
# 1485             [Action, Casual, Indie, RPG, Strategy]  Feb 28, 2023
# 1491                          [Casual, Indie, Strategy]   Mar 9, 2023
# 1494                          [Action, Indie, Strategy]  Mar 27, 2023
# 1496                      [Indie, Simulation, Strategy]   Aug 4, 2022
#
#       metacritic_score                                         categories
# 2                  NaN  [Single-player, Multi-player, PvP, Online PvP,...  \
# 14                90.0  [Single-player, Multi-player, PvP, Online PvP,...
# 20                90.0  [Single-player, Multi-player, PvP, Online PvP,...
# 28                80.0  [Single-player, Multi-player, PvP, Online PvP,...
# 30                84.0               [Single-player, Steam Trading Cards]
# ...                ...                                                ...
# 1475               NaN   [Single-player, Steam Achievements, Steam Cloud]
# 1485               NaN   [Single-player, Steam Achievements, Steam Cloud]
# 1491               NaN                                    [Single-player]
# 1494               NaN     [Single-player, Multi-player, PvP, Online PvP]
# 1496               NaN                                    [Single-player]
#
#       price_usd                                         developers
# 2           NaN                                        [BetaDwarf]  \
# 14        29.99  [CREATIVE ASSEMBLY, Feral Interactive (Mac), F...
# 20        29.99  [CREATIVE ASSEMBLY, Feral Interactive (Mac), F...
# 28        14.99                          [Double Fine Productions]
# 30        19.99                                           [Maxis™]
# ...         ...                                                ...
# 1475       9.99                                        [GamesBraz]
# 1485      14.99  [Absolute Power Game Studio, https://absolutep...
# 1491       2.99                                         [GANG DAN]
# 1494      34.99                                        [E2D2Works]
# 1496       1.99                                           [E-Cell]
#
#                                              publishers
# 2                                           [BetaDwarf]  \
# 14    [SEGA, Feral Interactive (Mac), Feral Interact...
# 20    [SEGA, Feral Interactive (Mac), Feral Interact...
# 28                            [Double Fine Productions]
# 30                                    [Electronic Arts]
# ...                                                 ...
# 1475                                        [GamesBraz]
# 1485                       [Absolute Power Game Studio]
# 1491                                         [GANG DAN]
# 1494                                        [E2D2Works]
# 1496                                           [E-Cell]
#
#                         owners
# 2     10,000,000 .. 20,000,000  \
# 14      2,000,000 .. 5,000,000
# 20      2,000,000 .. 5,000,000
# 28      2,000,000 .. 5,000,000
# 30      2,000,000 .. 5,000,000
# ...                        ...
# 1475               0 .. 20,000
# 1485               0 .. 20,000
# 1491               0 .. 20,000
# 1494               0 .. 20,000
# 1496               0 .. 20,000
#
#                                                    tags  owners_min
# 2     [Real Time Tactics, RTS, Multiplayer, Co-op, C...    10000000  \
# 14    [Strategy, Historical, Turn-Based Strategy, RT...     2000000
# 20    [Strategy, Historical, Turn-Based Strategy, RT...     2000000
# 28    [Action, Comedy, Adventure, Great Soundtrack, ...     2000000
# 30    [God Game, Open World, Exploration, Sandbox, C...     2000000
# ...                                                 ...         ...
# 1475  [Adventure, Action, Casual, Strategy, Action-A...           0
# 1485  [RPG, Strategy, Action, Board Game, Grand Stra...           0
# 1491  [Minimalist, Casual, Simulation, 2D Platformer...           0
# 1494  [Strategy, RTS, Action, Indie, Violent, Buildi...           0
# 1496  [Education, Science, RTS, Creature Collector, ...           0
#
#       owners_max
# 2       20000000
# 14       5000000
# 20       5000000
# 28       5000000
# 30       5000000
# ...          ...
# 1475       20000
# 1485       20000
# 1491       20000
# 1494       20000
# 1496       20000
#
# [339 rows x 13 columns]

# %%
df_steam_target.sort_values(by='owners_min', ascending=False).head(20)
# Out:
#      game_id                                              title
# 2     489520                                     Minion Masters  \
# 20     34330                                Total War: SHOGUN 2
# 28    225260                                      Brutal Legend
# 30     17390                                             SPORE™
# 33    244450                        Men of War: Assault Squad 2
# 14    201270                                Total War: SHOGUN 2
# 58    251060                                Wargame: Red Dragon
# 61    302670                                       Call to Arms
# 68    558100                              Art of War: Red Tides
# 70    568220  Lobotomy Corporation | Monster Management Simu...
# 71   1207590                        Builders of Egypt: Prologue
# 117    64000                          Men of War: Assault Squad
# 130   688420                          Bad North: Jotunn Edition
# 118   502520                        Ultimate General: Civil War
# 125  1029780                                     Going Medieval
# 116  1041320                                       Lords Mobile
# 108   443110                                    Armored Warfare
# 100    58610                       Wargame: European Escalation
# 113   773951                         Freeman: Guerrilla Warfare
# 277   464350                                     Screeps: World
#
#                                                 genres  release_date
# 2    [Action, Adventure, Free to Play, Indie, RPG, ...  May 24, 2019  \
# 20                                          [Strategy]  Mar 15, 2011
# 28                       [Action, Adventure, Strategy]  Feb 26, 2013
# 30   [Action, Adventure, Casual, RPG, Simulation, S...  Dec 19, 2008
# 33                      [Action, Simulation, Strategy]  May 15, 2014
# 14                                          [Strategy]  Mar 15, 2011
# 58                       [Indie, Simulation, Strategy]  Apr 17, 2014
# 61               [Action, Indie, Simulation, Strategy]  Apr 27, 2018
# 68   [Violent, Free to Play, Indie, Strategy, Early...  Dec 22, 2016
# 70                                 [Indie, Simulation]   Apr 9, 2018
# 71     [Free to Play, Indie, Simulation, Early Access]   Mar 2, 2020
# 117                                         [Strategy]  Feb 24, 2011
# 130                        [Action, Indie, Simulation]  Nov 16, 2018
# 118                      [Indie, Simulation, Strategy]  Jul 14, 2017
# 125   [Indie, RPG, Simulation, Strategy, Early Access]   Jun 1, 2021
# 116             [Massively Multiplayer, RPG, Strategy]   Jun 2, 2019
# 108  [Action, Adventure, Casual, Free to Play, Indi...  Nov 17, 2017
# 100                      [Indie, Simulation, Strategy]  Feb 22, 2012
# 113                     [Action, Indie, RPG, Strategy]   Oct 4, 2019
# 277  [Indie, Massively Multiplayer, Simulation, Str...  Nov 16, 2016
#
#      metacritic_score                                         categories
# 2                 NaN  [Single-player, Multi-player, PvP, Online PvP,...  \
# 20               90.0  [Single-player, Multi-player, PvP, Online PvP,...
# 28               80.0  [Single-player, Multi-player, PvP, Online PvP,...
# 30               84.0               [Single-player, Steam Trading Cards]
# 33               68.0  [Single-player, Multi-player, Co-op, Steam Ach...
# 14               90.0  [Single-player, Multi-player, PvP, Online PvP,...
# 58               78.0  [Single-player, Multi-player, PvP, Online PvP,...
# 61                NaN  [Single-player, Multi-player, PvP, Online PvP,...
# 68                NaN  [Multi-player, PvP, Online PvP, Co-op, Online ...
# 70                NaN                                    [Single-player]
# 71                NaN                                    [Single-player]
# 117              77.0  [Single-player, Multi-player, Co-op, Steam Ach...
# 130               NaN  [Single-player, Steam Achievements, Full contr...
# 118               NaN  [Single-player, Steam Achievements, Steam Trad...
# 125               NaN   [Single-player, Steam Achievements, Steam Cloud]
# 116               NaN  [Multi-player, MMO, PvP, Online PvP, Cross-Pla...
# 108               NaN  [Multi-player, MMO, PvP, Online PvP, Co-op, On...
# 100              81.0  [Single-player, Multi-player, PvP, Online PvP,...
# 113               NaN  [Single-player, Steam Achievements, Steam Trad...
# 277               NaN  [Single-player, Multi-player, MMO, PvP, Online...
#
#      price_usd                                         developers
# 2          NaN                                        [BetaDwarf]  \
# 20       29.99  [CREATIVE ASSEMBLY, Feral Interactive (Mac), F...
# 28       14.99                          [Double Fine Productions]
# 30       19.99                                           [Maxis™]
# 33       29.99                                  [Digitalmindsoft]
# 14       29.99  [CREATIVE ASSEMBLY, Feral Interactive (Mac), F...
# 58       29.99                                    [Eugen Systems]
# 61       14.99                                  [Digitalmindsoft]
# 68         NaN                                     [Game Science]
# 70       24.99                                      [ProjectMoon]
# 71         NaN                                    [Strategy Labs]
# 117       9.99                                  [Digitalmindsoft]
# 130      14.99                [Plausible Concept, Oskar Stålberg]
# 118      29.99                                        [Game-Labs]
# 125      24.99                                       [Foxy Voxel]
# 116        NaN                          [IGG SINGAPORE PTE. LTD.]
# 108        NaN           [Obsidian Entertainment, Wishlist Games]
# 100       9.99                                    [Eugen Systems]
# 113      24.99                                   [KK Game Studio]
# 277      14.99                                     [Screeps, LLC]
#
#                                             publishers
# 2                                          [BetaDwarf]  \
# 20   [SEGA, Feral Interactive (Mac), Feral Interact...
# 28                           [Double Fine Productions]
# 30                                   [Electronic Arts]
# 33                                [Fulqrum Publishing]
# 14   [SEGA, Feral Interactive (Mac), Feral Interact...
# 58                                     [Eugen Systems]
# 61                                   [Digitalmindsoft]
# 68                                      [Game Science]
# 70                                       [ProjectMoon]
# 71   [Strategy Labs, PlayWay S.A., CreativeForge Ga...
# 117                               [Fulqrum Publishing]
# 130                                         [Raw Fury]
# 118                                        [Game-Labs]
# 125                        [The Irregular Corporation]
# 116                          [IGG SINGAPORE PTE. LTD.]
# 108                                   [Wishlist Games]
# 100                                    [Eugen Systems]
# 113                                   [KK Game Studio]
# 277                                     [Screeps, LLC]
#
#                        owners
# 2    10,000,000 .. 20,000,000  \
# 20     2,000,000 .. 5,000,000
# 28     2,000,000 .. 5,000,000
# 30     2,000,000 .. 5,000,000
# 33     2,000,000 .. 5,000,000
# 14     2,000,000 .. 5,000,000
# 58     1,000,000 .. 2,000,000
# 61     1,000,000 .. 2,000,000
# 68     1,000,000 .. 2,000,000
# 70     1,000,000 .. 2,000,000
# 71     1,000,000 .. 2,000,000
# 117      500,000 .. 1,000,000
# 130      500,000 .. 1,000,000
# 118      500,000 .. 1,000,000
# 125      500,000 .. 1,000,000
# 116      500,000 .. 1,000,000
# 108      500,000 .. 1,000,000
# 100      500,000 .. 1,000,000
# 113      500,000 .. 1,000,000
# 277        200,000 .. 500,000
#
#                                                   tags  owners_min  owners_max
# 2    [Real Time Tactics, RTS, Multiplayer, Co-op, C...    10000000    20000000
# 20   [Strategy, Historical, Turn-Based Strategy, RT...     2000000     5000000
# 28   [Action, Comedy, Adventure, Great Soundtrack, ...     2000000     5000000
# 30   [God Game, Open World, Exploration, Sandbox, C...     2000000     5000000
# 33   [Strategy, World War II, War, Simulation, RTS,...     2000000     5000000
# 14   [Strategy, Historical, Turn-Based Strategy, RT...     2000000     5000000
# 58   [Strategy, RTS, Military, Realistic, Wargame, ...     1000000     2000000
# 61   [Strategy, Military, Action, Multiplayer, RTS,...     1000000     2000000
# 68   [Free to Play, Strategy, Multiplayer, RTS, Ear...     1000000     2000000
# 70   [Management, Difficult, Simulation, Story Rich...     1000000     2000000
# 71   [Free to Play, Simulation, City Builder, Indie...     1000000     2000000
# 117  [Strategy, World War II, Tactical, War, RTS, M...      500000     1000000
# 130  [Real Time Tactics, Minimalist, Rogue-lite, To...      500000     1000000
# 118  [Strategy, War, Historical, RTS, Simulation, T...      500000     1000000
# 125  [Early Access, City Builder, Medieval, Colony ...      500000     1000000
# 116  [Free to Play, Strategy, Massively Multiplayer...      500000     1000000
# 108  [Tanks, Free to Play, Action, Multiplayer, Veh...      500000     1000000
# 100  [Strategy, RTS, Military, Cold War, Wargame, R...      500000     1000000
# 113  [Strategy, Action, Shooter, FPS, RPG, First-Pe...      500000     1000000
# 277  [Programming, Strategy, Massively Multiplayer,...      200000      500000

# %% [markdown]
# #### Saving Steam store game data

# %%
df_steam_full.to_csv('steam_rts_full.csv', mode='w')

# %%
df_steam_target.to_csv('steam_rts_target.csv', mode='w')
